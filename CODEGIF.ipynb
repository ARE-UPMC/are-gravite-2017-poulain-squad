# %%
"COPYRIGHT MOSTI"
#Code animation:

from pylab import *
import numpy as np
import os, time
import PIL 
from PIL import Image 
from PIL.GifImagePlugin import getheader, getdata 


im1 = Image.open("1.png")
im2 = Image.open("2.png")
im3 = Image.open("3.png")
im4 = Image.open("4.png")
im5 = Image.open("5.png")
im6 = Image.open("6.png")
im7 = Image.open("7.png")
im8 = Image.open("8.png")
im9 = Image.open("9.png")
im10 = Image.open("10.png")
im11 = Image.open("11.png")
im12 = Image.open("12.png")

List_i = []
List_j = []

List_i.append(im1.size[0]) 
List_j.append(im1.size[1]) 
List_i.append(im2.size[0]) 
List_j.append(im2.size[1]) 
List_i.append(im3.size[0]) 
List_j.append(im3.size[1]) 
List_i.append(im4.size[0]) 
List_j.append(im4.size[1]) 
List_i.append(im5.size[0]) 
List_j.append(im5.size[1])
List_i.append(im6.size[0]) 
List_j.append(im6.size[1]) 
List_i.append(im7.size[0]) 
List_j.append(im7.size[1]) 
List_i.append(im8.size[0]) 
List_j.append(im8.size[1]) 
List_i.append(im9.size[0]) 
List_j.append(im9.size[1]) 
List_i.append(im10.size[0]) 
List_j.append(im10.size[1])
List_i.append(im11.size[0]) 
List_j.append(im11.size[1]) 
List_i.append(im12.size[0]) 
List_j.append(im12.size[1])

pad = 4

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im1, (0+pad,0+pad))
new_im.save("1_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im2, (0+pad,0+pad))
new_im.save("2_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im3, (0+pad,0+pad))
new_im.save("3_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im4, (0+pad,0+pad))
new_im.save("4_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im5, (0+pad,0+pad))
new_im.save("5_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im1, (0+pad,0+pad))
new_im.save("6_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im2, (0+pad,0+pad))
new_im.save("7_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im3, (0+pad,0+pad))
new_im.save("8_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im4, (0+pad,0+pad))
new_im.save("9_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im5, (0+pad,0+pad))
new_im.save("10_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im4, (0+pad,0+pad))
new_im.save("11_adjusted.png", "PNG")

new_im = Image.new('RGB', (max(List_i)+pad,max(List_j)+pad),(255,255,255))
new_im.paste(im5, (0+pad,0+pad))
new_im.save("12_adjusted.png", "PNG")

# Convertir l'image en gif

os.system('convert -delay 100 *_adjusted.png animation.gif')
